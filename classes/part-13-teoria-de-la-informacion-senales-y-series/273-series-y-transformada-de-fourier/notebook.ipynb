# %% [markdown]
# # 273 — Series y transformada de Fourier
#
# **Parte 13 · Teoría de la información, señales y series** · nivel `avanzado`
#
# Notebook de recorrido. Ejecuta la demostración `fourier_series` del motor `part13` y comenta cada salida.

# %% [markdown]
# ## 1. Contexto
#
# Entropía, entropía cruzada, divergencias, información mutua, codificación, muestreo, convolución, Fourier, FFT, filtros y series temporales.
#
# > KL no es simétrica ni es una distancia; JS sí es simétrica.

# %%
import json, sys
from pathlib import Path
ROOT = Path.cwd()
while ROOT != ROOT.parent and not (ROOT / 'curriculum.yaml').exists():
    ROOT = ROOT.parent
sys.path.insert(0, str(ROOT / 'src'))
from computational_math.engines import part13 as motor
demo = motor.DEMOS['fourier_series']
print(demo.__doc__)

# %% [markdown]
# ## 2. Ejecución
#
# Antes de ejecutar la celda siguiente, escribe aquí tu predicción:
#
# - Caso normal:
# - Caso límite:
# - Caso inválido:

# %%
resultado = demo()
print(json.dumps(resultado, indent=2, ensure_ascii=False, default=str))

# %% [markdown]
# ## 3. Lectura de las salidas
#
# La demostración devuelve 8 valores. Identifica cuáles son **resultados** y cuáles son **comprobaciones de invariante**.

# %%
for clave, valor in resultado.items():
    tipo = type(valor).__name__
    print(f'{clave:45s} {tipo:10s} {str(valor)[:60]}')

# %% [markdown]
# ## 4. Fuente
#
# Lee la implementación y localiza dónde ocurre cada paso del razonamiento.

# %%
import inspect
print(inspect.getsource(demo))

# %% [markdown]
# ## 5. Reflexión
#
# Responde sin volver a mirar el código:
#
# 1. ¿Qué supuesto hiciste?
# 2. ¿Cómo verificaste el cálculo por un camino independiente?
# 3. ¿Qué cambiaría en un caso límite?
# 4. Error a evitar en esta parte: *Calcular log(0) sin epsilon de estabilidad.*
