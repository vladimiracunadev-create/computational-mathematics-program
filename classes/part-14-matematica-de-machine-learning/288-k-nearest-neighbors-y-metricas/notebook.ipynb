# %% [markdown]
# # 288 — k-Nearest Neighbors y métricas
#
# **Parte 14 · Matemática de Machine Learning** · nivel `ml-avanzado`
#
# Notebook de recorrido. Ejecuta la demostración `knn` del motor `part14` y comenta cada salida.

# %% [markdown]
# ## 1. Contexto
#
# Derivación matemática de los algoritmos clásicos: regresión, regularización, clasificación, kernels, árboles, ensambles, clustering, EM y compromiso sesgo-varianza.
#
# > El kernel trick evita construir el espacio de características explícitamente.

# %%
import json, sys
from pathlib import Path
ROOT = Path.cwd()
while ROOT != ROOT.parent and not (ROOT / 'curriculum.yaml').exists():
    ROOT = ROOT.parent
sys.path.insert(0, str(ROOT / 'src'))
from computational_math.engines import part14 as motor
demo = motor.DEMOS['knn']
print(demo.__doc__)

# %% [markdown]
# ## 2. Ejecución
#
# Antes de ejecutar la celda siguiente, escribe aquí tu predicción:
#
# - Caso normal:
# - Caso límite:
# - Caso inválido:

# %%
resultado = demo()
print(json.dumps(resultado, indent=2, ensure_ascii=False, default=str))

# %% [markdown]
# ## 3. Lectura de las salidas
#
# La demostración devuelve 9 valores. Identifica cuáles son **resultados** y cuáles son **comprobaciones de invariante**.

# %%
for clave, valor in resultado.items():
    tipo = type(valor).__name__
    print(f'{clave:45s} {tipo:10s} {str(valor)[:60]}')

# %% [markdown]
# ## 4. Fuente
#
# Lee la implementación y localiza dónde ocurre cada paso del razonamiento.

# %%
import inspect
print(inspect.getsource(demo))

# %% [markdown]
# ## 5. Reflexión
#
# Responde sin volver a mirar el código:
#
# 1. ¿Qué supuesto hiciste?
# 2. ¿Cómo verificaste el cálculo por un camino independiente?
# 3. ¿Qué cambiaría en un caso límite?
# 4. Error a evitar en esta parte: *No estandarizar antes de aplicar regularización o k-NN.*
